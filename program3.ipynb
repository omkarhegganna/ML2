# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarhegganna/ML2/blob/main/program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 3: Find-S Algorithm

import csv

# Read dataset
filename = input("Enter CSV file name: ")

with open(filename, 'r') as file:
    data = list(csv.reader(file))

# Separate header and examples
header = data[0]
examples = data[1:]

# Last column is the target/class
attributes = header[:-1]

# Find first positive example
hypothesis = None

for row in examples:
    if row[-1].lower() == "yes":
        hypothesis = row[:-1].copy()
        break

# Apply Find-S
for row in examples:
    if row[-1].lower() == "yes":
        for i in range(len(hypothesis)):
            if hypothesis[i] != row[i]:
                hypothesis[i] = "?"

# Display final hypothesis
print("Final Hypothesis:", hypothesis)
print("Attributes:", attributes)
print("Examples:", examples)
# Out:
# Enter CSV file name: weather_forecast.csv
# Final Hypothesis: ['?', '?', '?', '?']
# Attributes: ['Outlook', 'Temperature', 'Humidity', 'Windy']
# Examples: [['Sunny', 'Hot', 'High', 'Weak', 'No'], ['Sunny', 'Hot', 'High', 'Strong', 'No'], ['Overcast', 'Hot', 'High', 'Weak', 'Yes'], ['Rain', 'Mild', 'High', 'Weak', 'Yes'], ['Rain', 'Cool', 'Normal', 'Weak', 'Yes'], ['Rain', 'Cool', 'Normal', 'Strong', 'No'], ['Overcast', 'Cool', 'Normal', 'Strong', 'Yes'], ['Sunny', 'Mild', 'High', 'Weak', 'No'], ['Sunny', 'Cool', 'Normal', 'Weak', 'Yes'], ['Rain', 'Mild', 'Normal', 'Weak', 'Yes'], ['Sunny', 'Mild', 'Normal', 'Strong', 'Yes'], ['Overcast', 'Mild', 'High', 'Strong', 'Yes'], ['Overcast', 'Hot', 'Normal', 'Weak', 'Yes'], ['Rain', 'Mild', 'High', 'Strong', 'No']]
